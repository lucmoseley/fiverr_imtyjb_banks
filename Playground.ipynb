# %%
import numpy as np
import pandas as pd

# %%
pd.read_excel('personal-loan.xls', index_col=0)
# Out:
#               Unnamed: 1      Unnamed: 2   Unnamed: 3  \
# personal-loan
# customer_id          age  yrs_experience  family_size
# NaN                  NaN             NaN          NaN
# 3815                  40               9            3
# NaN                  NaN             NaN          NaN
# 5737                  65              27            4
# ...                  ...             ...          ...
# 2454                  34              11            2
# NaN                  NaN             NaN          NaN
# 1435                  30             NaN            2
# NaN                  NaN             NaN          NaN
# 1409                  47              22            3
#
#                              Unnamed: 4 Unnamed: 5    Unnamed: 6  \
# personal-loan
# customer_id             education_level     income  mortgage_amt
# NaN                                 NaN        NaN           NaN
# 3815                           Graduate         60             0
# ...
